# %%
import pandas as pd

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0].head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df = df[0]

# %%
df.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df.dtypes.head()
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# dtype: object

# %%
df[['ORB', 'DRB', 'TRB', 'AST',	'STL']].head()
# Out:
#    ORB  DRB  TRB  AST STL
# 0   79  222  301   68  27
# 1    9   19   28   16  16
# 2  199  324  523   66  38
# 3   23   54   77   15   4
# 4   27  220  247  129  41

# %%
df.to_csv('data/sample-csv/0227_NBA.csv', index=False)

# %%
d = """
{
    "name": "John Doe",
    "email": "John.Doe@company.com",
    "tech": ["ML", "DL", "CV", "NLP", "RL", "BD", "DA"],
    "platform": ["techneuron", "kidsneuron", "ineuron"]
}
"""

# %%
type(d)
# Out:
# str

# %%
import json

# %%
result = json.loads(d)

# %%
result
# Out:
# {'name': 'John Doe',
#  'email': 'John.Doe@company.com',
#  'tech': ['ML', 'DL', 'CV', 'NLP', 'RL', 'BD', 'DA'],
#  'platform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
type(result)
# Out:
# dict

# %%
d = """
{
    "name": "John Doe",
    "email": "John.Doe@company.com",
    "tech": ["ML", "DL", "CV"],
    "platform": ["techneuron", "kidsneuron", "ineuron"]
}
"""

# %%
result = json.loads(d)

# %%
pd.DataFrame(result)
# Out:
#        name                 email tech    platform
# 0  John Doe  John.Doe@company.com   ML  techneuron
# 1  John Doe  John.Doe@company.com   DL  kidsneuron
# 2  John Doe  John.Doe@company.com   CV     ineuron

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url).head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                             html_url          id  \
# 0    https://github.com/pandas-dev/pandas/pull/50618  1523490755
# 1  https://github.com/pandas-dev/pandas/issues/50617  1523487004
# 2    https://github.com/pandas-dev/pandas/pull/50616  1523466294
# 3  https://github.com/pandas-dev/pandas/issues/50615  1523413757
# 4    https://github.com/pandas-dev/pandas/pull/50614  1523380130
#
#                node_id  number  \
# 0  PR_kwDOAA0YD85G3e2T   50618
# 1   I_kwDOAA0YD85azpEc   50617
# 2  PR_kwDOAA0YD85G3ZU-   50616
# 3   I_kwDOAA0YD85azXL9   50615
# 4  PR_kwDOAA0YD85G3HKC   50614
#
#                                                title  ... closed_at  \
# 0                                   WIP: CoW Replace  ...       NaT
# 1       DEPR: Series.__getitem__, Series.__setitem__  ...       NaT
# 2                               ENH: DTI/TDI as_unit  ...       NaT
# 3  BUG: Custom `__repr__` method not used when pr...  ...       NaT
# 4  CLN/BUG: Allow assert_produces_warning to rais...  ...       NaT
#
#   author_association active_lock_reason  draft  \
# 0             MEMBER                NaN    1.0
# 1             MEMBER                NaN    NaN
# 2             MEMBER                NaN    0.0
# 3               NONE                NaN    NaN
# 4             MEMBER                NaN    0.0
#
#                                         pull_request  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1                                                NaN
# 2  {'url': 'https://api.github.com/repos/pandas-d...
# 3                                                NaN
# 4  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                                 body  \
# 0  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 1  Trying to guess whether e.g. `ser[2]`, `ser[:2...
# 2  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 3  ### Pandas version checks\n\n- [X] I have chec...
# 4  Fixes this case that would not raise an `Asser...
#
#                                            reactions  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1  {'url': 'https://api.github.com/repos/pandas-d...
# 2  {'url': 'https://api.github.com/repos/pandas-d...
# 3  {'url': 'https://api.github.com/repos/pandas-d...
# 4  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                         timeline_url performed_via_github_app  \
# 0  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 1  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 2  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 3  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 4  https://api.github.com/repos/pandas-dev/pandas...                      NaN
#
#   state_reason
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 30 columns]

# %%
import requests

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
type(data)
# Out:
# requests.models.Response

# %%
data = data.json()

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50618',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50618/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50618/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50618/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50618',
#   'id': 1523490755,
#   'node_id': 'PR_kwDOAA0YD85G3e2T',
#   'number': 50618,
#   'title': 'WIP: CoW Replace',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-07T05:29:15Z',
#   'updated_at': '2023-01-07T05:29:15Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50618',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50618',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50618.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50618.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nSits on top of #50148. (will rebase afterwards).\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50618/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50618/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50617',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50617/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50617/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50617/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50617',
#   'id': 1523487004,
#   'node_id': 'I_kwDOAA0YD85azpEc',
#   'number': 50617,
#   'title': 'DEPR: Series.__getitem__, Series.__setitem__',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-07T05:20:34Z',
#   'updated_at': '2023-01-07T05:20:53Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "Trying to guess whether e.g. `ser[2]`, `ser[:2]` is intended to be positional or label-based is a hassle, and in the slicing case we are inconsistent about it.  Let's get rid of this problem once and for all by deprecating these and telling users to use loc or iloc instead.\r\n\r\nDiscussed in #49612\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50617/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50617/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50616',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50616/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50616/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50616/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50616',
#   'id': 1523466294,
#   'node_id': 'PR_kwDOAA0YD85G3ZU-',
#   'number': 50616,
#   'title': 'ENH: DTI/TDI as_unit',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-07T04:41:14Z',
#   'updated_at': '2023-01-07T04:41:14Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50616',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50616',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50616.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50616.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50616/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50616/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50615',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50615/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50615/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50615/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50615',
#   'id': 1523413757,
#   'node_id': 'I_kwDOAA0YD85azXL9',
#   'number': 50615,
#   'title': 'BUG: Custom `__repr__` method not used when printing NamedTuples in DataFrame',
#   'user': {'login': 'dasistkeintest',
#    'id': 67752255,
#    'node_id': 'MDQ6VXNlcjY3NzUyMjU1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67752255?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dasistkeintest',
#    'html_url': 'https://github.com/dasistkeintest',
#    'followers_url': 'https://api.github.com/users/dasistkeintest/followers',
#    'following_url': 'https://api.github.com/users/dasistkeintest/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dasistkeintest/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dasistkeintest/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dasistkeintest/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dasistkeintest/orgs',
#    'repos_url': 'https://api.github.com/users/dasistkeintest/repos',
#    'events_url': 'https://api.github.com/users/dasistkeintest/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dasistkeintest/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-07T02:32:01Z',
#   'updated_at': '2023-01-07T02:32:01Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nfrom typing import NamedTuple\r\n\r\nimport pandas as pd\r\n\r\n\r\nclass Person(NamedTuple):\r\n    name: str\r\n    age: int\r\n\r\n    def __repr__(self):\r\n        return self.name\r\n\r\n\r\na = Person("Alice", 20)\r\nprint(a)\r\n\r\ndf = pd.DataFrame([[a]])\r\nprint(df)\n```\n\n\n### Issue Description\n\nWhen printing a DataFrame containing NamedTuples, the default string representation for tuples is used rather than a custom string representation defined by the `__repr__` method of the NamedTuple class.\n\n### Expected Behavior\n\nI would expect the `__repr__` method of the object to be used.\n\n### Installed Versions\n\n<details>\r\n\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 8dab54d6573f7186ff0c3b6364d5e4dd635ff3e7\r\npython           : 3.11.1.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.22621\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 126 Stepping 5, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United Kingdom.1252\r\n\r\npandas           : 1.5.2\r\nnumpy            : 1.24.1\r\npytz             : 2022.7\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.5.0\r\npip              : 22.3.1\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : 8.8.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.6.2\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.10.0\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50615/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50615/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50614',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50614/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50614/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50614/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50614',
#   'id': 1523380130,
#   'node_id': 'PR_kwDOAA0YD85G3HKC',
#   'number': 50614,
#   'title': 'CLN/BUG: Allow assert_produces_warning to raise during an exception',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None},
#    {'id': 1628184320,
#     'node_id': 'MDU6TGFiZWwxNjI4MTg0MzIw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Warnings',
#     'name': 'Warnings',
#     'color': 'f2f074',
#     'default': False,
#     'description': 'Warnings that appear or should be added to pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-07T01:19:07Z',
#   'updated_at': '2023-01-07T01:19:07Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50614',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50614',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50614.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50614.patch',
#    'merged_at': None},
#   'body': 'Fixes this case that would not raise an `AssertionError` before\r\n\r\n```\r\nwith pytest.raises(...):\r\n    with tm.assert_produces_warning(UserWarning):\r\n        raise ...\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50614/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50614/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50612',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50612/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50612/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50612/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50612',
#   'id': 1523332043,
#   'node_id': 'PR_kwDOAA0YD85G2-kk',
#   'number': 50612,
#   'title': 'DEPR: Enforce disallowing 2 positional args in DataFrame.reindex',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-07T00:09:10Z',
#   'updated_at': '2023-01-07T09:33:03Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50612',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50612',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50612.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50612.patch',
#    'merged_at': None},
#   'body': 'Introduced in #17966',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50612/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50612/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50611',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50611/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50611/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50611/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50611',
#   'id': 1523331076,
#   'node_id': 'PR_kwDOAA0YD85G2-Y3',
#   'number': 50611,
#   'title': 'BUG/ENH: infer_freq with non-nano',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-07T00:07:52Z',
#   'updated_at': '2023-01-07T00:07:52Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50611',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50611',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50611.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50611.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50611/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50611/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50609',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50609/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50609/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50609/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50609',
#   'id': 1523240761,
#   'node_id': 'PR_kwDOAA0YD85G2sqy',
#   'number': 50609,
#   'title': "DOC: update docstrings of Interval's attributes",
#   'user': {'login': 'abonte',
#    'id': 6319051,
#    'node_id': 'MDQ6VXNlcjYzMTkwNTE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6319051?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/abonte',
#    'html_url': 'https://github.com/abonte',
#    'followers_url': 'https://api.github.com/users/abonte/followers',
#    'following_url': 'https://api.github.com/users/abonte/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/abonte/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/abonte/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/abonte/subscriptions',
#    'organizations_url': 'https://api.github.com/users/abonte/orgs',
#    'repos_url': 'https://api.github.com/users/abonte/repos',
#    'events_url': 'https://api.github.com/users/abonte/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/abonte/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-06T22:09:32Z',
#   'updated_at': '2023-01-07T07:27:21Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50609',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50609',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50609.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50609.patch',
#    'merged_at': None},
#   'body': 'Added _See Also_ and/or _Examples_ sections in the docstrings of Interval\'s attributes:\r\n\r\n<details><summary>closed_left, output from `validate_docstrings.py`</summary>\r\n<p>\r\n\r\n```\r\n\ufeff\ufeff\ufeff################################################################################\r\n################### Docstring (pandas.Interval.closed_left)  ###################\r\n################################################################################\r\n\r\nCheck if the interval is closed on the left side.\r\n\r\nFor the meaning of `closed` and `open` see :class:`~pandas.Interval`.\r\n\r\nReturns\r\n-------\r\nbool\r\n    True if the Interval is closed on the left-side.\r\n\r\nSee Also\r\n--------\r\nInterval.closed_right : Check if the interval is closed on the right side.\r\nInterval.open_left : Boolean inverse of closed_left.\r\n\r\nExamples\r\n--------\r\n>>> iv = pd.Interval(0, 5, closed=\'left\')\r\n>>> iv.closed_left\r\nTrue\r\n\r\n>>> iv = pd.Interval(0, 5, closed=\'right\')\r\n>>> iv.closed_left\r\nFalse\r\n\r\n################################################################################\r\n################################## Validation ##################################\r\n################################################################################\r\n\r\nDocstring for "pandas.Interval.closed_left" correct. :)\r\n```\r\n</p>\r\n</details>\r\n\r\n<details><summary>closed_right, output from `validate_docstrings.py`</summary>\r\n<p>\r\n\r\n```\r\n################################################################################\r\n################### Docstring (pandas.Interval.closed_right) ###################\r\n################################################################################\r\n\r\nCheck if the interval is closed on the right side.\r\n\r\nFor the meaning of `closed` and `open` see :class:`~pandas.Interval`.\r\n\r\nReturns\r\n-------\r\nbool\r\n    True if the Interval is closed on the left-side.\r\n\r\nSee Also\r\n--------\r\nInterval.closed_left : Check if the interval is closed on the left side.\r\nInterval.open_right : Boolean inverse of closed_right.\r\n\r\nExamples\r\n--------\r\n>>> iv = pd.Interval(0, 5, closed=\'both\')\r\n>>> iv.closed_right\r\nTrue\r\n\r\n>>> iv = pd.Interval(0, 5, closed=\'left\')\r\n>>> iv.closed_right\r\nFalse\r\n\r\n################################################################################\r\n################################## Validation ##################################\r\n################################################################################\r\n\r\nDocstring for "pandas.Interval.closed_right" correct. :)\r\n```\r\n</p>\r\n</details>\r\n<details><summary>open_left, output from `validate_docstrings.py`</summary>\r\n<p>\r\n\r\n```\r\n################################################################################\r\n#################### Docstring (pandas.Interval.open_left)  ####################\r\n################################################################################\r\n\r\nCheck if the interval is open on the left side.\r\n\r\nFor the meaning of `closed` and `open` see :class:`~pandas.Interval`.\r\n\r\nReturns\r\n-------\r\nbool\r\n    True if the Interval is not closed on the left-side.\r\n\r\nSee Also\r\n--------\r\nInterval.open_right : Check if the interval is open on the right side.\r\nInterval.closed_left : Boolean inverse of open_left.\r\n\r\nExamples\r\n--------\r\n>>> iv = pd.Interval(0, 5, closed=\'neither\')\r\n>>> iv.open_left\r\nTrue\r\n\r\n>>> iv = pd.Interval(0, 5, closed=\'both\')\r\n>>> iv.open_left\r\nFalse\r\n\r\n################################################################################\r\n################################## Validation ##################################\r\n################################################################################\r\n\r\nDocstring for "pandas.Interval.open_left" correct. :)\r\n ```\r\n</p>\r\n</details>\r\n<details><summary>open_right, output from `validate_doc ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50609/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50609/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50607',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50607/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50607/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50607/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50607',
#   'id': 1523161203,
#   'node_id': 'I_kwDOAA0YD85ayZhz',
#   'number': 50607,
#   'title': 'BUG: Inconsistent apply(axis=1) behavior',
#   'user': {'login': 'MichaelTiemannOSC',
#    'id': 72577720,
#    'node_id': 'MDQ6VXNlcjcyNTc3NzIw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72577720?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MichaelTiemannOSC',
#    'html_url': 'https://github.com/MichaelTiemannOSC',
#    'followers_url': 'https://api.github.com/users/MichaelTiemannOSC/followers',
#    'following_url': 'https://api.github.com/users/MichaelTiemannOSC/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MichaelTiemannOSC/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MichaelTiemannOSC/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MichaelTiemannOSC/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MichaelTiemannOSC/orgs',
#    'repos_url': 'https://api.github.com/users/MichaelTiemannOSC/repos',
#    'events_url': 'https://api.github.com/users/MichaelTiemannOSC/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MichaelTiemannOSC/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 307649777,
#     'node_id': 'MDU6TGFiZWwzMDc2NDk3Nzc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Info',
#     'name': 'Needs Info',
#     'color': '207de5',
#     'default': False,
#     'description': 'Clarification about behavior needed to assess issue'},
#    {'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-01-06T21:01:21Z',
#   'updated_at': '2023-01-07T00:59:29Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport numpy as np\r\nimport pandas as pd\r\nimport pint\r\nfrom pint import set_application_registry\r\nimport pint_pandas\r\nfrom openscm_units import unit_registry\r\n\r\nureg = unit_registry\r\nset_application_registry(ureg)\r\npint.Quantity = ureg.Quantity\r\npint.Unit = ureg.Unit\r\npint.Measurement = ureg.Measurement\r\npint.Context = ureg.Context\r\n\r\nureg.define("CO2e = CO2 = CO2eq = CO2_eq")\r\nureg.define("boe = 6.1178632 GJ")\r\nureg.define("Cement = [cement]")\r\nureg.define("Petrochemicals = [petrochemicals]")\r\n\r\nQ_ = Quantity = ureg.Quantity\r\n\r\nxx = pd.DataFrame([\r\n    pd.Series(data=[19.0, 18.0, 17.0],index=[2019, 2020, 2021], name=(\'FR0000120271\', \'s1s2\'), dtype=\'pint[CO2e * kilogram / boe]\'),\r\n    pd.Series(data=[68.0, 68.0, 67.0],index=[2019, 2020, 2021], name=(\'IT0003132476\', \'s1s2s3\'), dtype=\'pint[CO2 * gram / megajoule]\'),\r\n    pd.Series(data=[0.0279, 0.027, np.nan],index=[2019, 2020, 2021], name=(\'US6745991058-oil\', \'s1\'), dtype=\'pint[CO2e * megametric_ton / boe]\'),\r\n    pd.Series(data=[0.0059, 0.0059, np.nan],index=[2019, 2020, 2021], name=(\'US6745991058-oil\', \'s2\'), dtype=\'pint[CO2e * megametric_ton / boe]\'),\r\n    pd.Series(data=[0.0338, 0.0329, np.nan],index=[2019, 2020, 2021], name=(\'US6745991058-oil\', \'s1s2\'), dtype=\'pint[CO2e * megametric_ton / boe]\'),\r\n    pd.Series(data=[0.515, 0.551, np.nan],index=[2019, 2020, 2021], name=(\'US6745991058-chem\', \'s1\'), dtype=\'pint[CO2e / Petrochemicals]\'),\r\n    pd.Series(data=[0.157, 0.148, np.nan],index=[2019, 2020, 2021], name=(\'US6745991058-chem\', \'s2\'), dtype=\'pint[CO2e / Petrochemicals]\'),\r\n    pd.Series(data=[0.671, 0.698, np.nan],index=[2019, 2020, 2021], name=(\'US6745991058-chem\', \'s1s2\'), dtype=\'pint[CO2e / Petrochemicals]\'),\r\n    pd.Series(data=[660.0, 643.0, 643.0],index=[2019, 2020, 2021], name=(\'IE0001827041\', \'s1s2s3\'), dtype=\'pint[CO2e * kilogram / Cement / metric_ton]\'),\r\n    pd.Series(data=[641.0, np.nan, np.nan],index=[2019, 2020, 2021], name=(\'IE0001827041\', \'s1s2s3\'), dtype=\'pint[CO2e * kilogram / Cement / metric_ton]\'),\r\n    pd.Series(data=[np.nan, np.nan, np.nan],index=[2019, 2020, 2021], name=(\'IE0001827041\', \'s1s2s3\'), dtype=\'pint[CO2e * kilogram / Cement / metric_ton]\'),\r\n    pd.Series(data=[np.nan, np.nan, np.nan],index=[2019, 2020, 2021], name=(\'IE0001827041\', \'s1s2s3\'), dtype=\'pint[CO2e * kilogram / Cement / metric_ton]\'),\r\n    pd.Series(data=[54.8, 47.2, 44.2],index=[2019, 2020, 2021], name=(\'JE00B2419D89\', \'s1s2\'), dtype=\'pint[CO2e * kilogram / Cement / metric_ton]\')])\r\nxx.index.names=[\'company_id\', \'scope\']\r\n\r\ndef asPintSeries(series: pd.Series, name=None, errors=\'ignore\', inplace=False) -> pd.Series:\r\n    """\r\n    Parameters\r\n    ----------\r\n    series : pd.Series possibly containing Quantity values, not already in a PintArray.\r\n    name : the name to give to the resulting series\r\n    errors : { \'raise\', \'ignore\' }, default \'ignore\'\r\n    inplace : bool, default False\r\n             If True, perform operation in-place.\r\n\r\n    Returns\r\n    -------\r\n    If there is only one type of unit in the series, a PintArray version of the series,\r\n    replacing NULL values with Quantity (np.nan, unit_type).\r\n\r\n    Raises ValueError if there are more than one type of units in the series.\r\n    Silently series if no conversion needed to be done.\r\n    """\r\n    if series.dtype != \'O\':\r\n        if errors == \'ignore\':\r\n            return series\r\n        if name:\r\n            raise ValueError ("\'{name}\' not dtype(\'O\')")\r\n      ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50607/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50607/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50606',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50606/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50606/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50606/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50606',
#   'id': 1523022262,
#   'node_id': 'PR_kwDOAA0YD85G197u',
#   'number': 50606,
#   'title': 'REGR: Fix regression in to_numpy',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/42',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42/labels',
#    'id': 1945020,
#    'node_id': 'MDk6TWlsZXN0b25lMTk0NTAyMA==',
#    'number': 42,
#    'title': '2.0',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 63,
#    'closed_issues': 958,
#    'state': 'open',
#    'created_at': '2016-08-16T13:21:24Z',
#    'updated_at': '2023-01-07T09:39:59Z',
#    'due_on': '2023-01-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-01-06T19:12:07Z',
#   'updated_at': '2023-01-06T23:12:46Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50606',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50606',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50606.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50606.patch',
#    'merged_at': None},
#   'body': '- [x] closes #50600 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\ncc @mroeschke ',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50606/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50606/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50603',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50603/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50603/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50603/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50603',
#   'id': 1522839181,
#   'node_id': 'I_kwDOAA0YD85axK6N',
#   'number': 50603,
#   'title': 'QST: Is there a work-around for repeated FutureWarnings?',
#   'user': {'login': 'stev-0',
#    'id': 1316871,
#    'node_id': 'MDQ6VXNlcjEzMTY4NzE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1316871?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stev-0',
#    'html_url': 'https://github.com/stev-0',
#    'followers_url': 'https://api.github.com/users/stev-0/followers',
#    'following_url': 'https://api.github.com/users/stev-0/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/stev-0/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/stev-0/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/stev-0/subscriptions',
#    'organizations_url': 'https://api.github.com/users/stev-0/orgs',
#    'repos_url': 'https://api.github.com/users/stev-0/repos',
#    'events_url': 'https://api.github.com/users/stev-0/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/stev-0/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 34444536,
#     'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#     'name': 'Usage Question',
#     'color': '0052cc',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2023-01-06T16:31:01Z',
#   'updated_at': '2023-01-06T20:00:17Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
# ...
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2023-01-04T22:19:27Z',
#   'updated_at': '2023-01-06T18:51:01Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50573',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50573',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50573.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50573.patch',
#    'merged_at': None},
#   'body': '- [ ] xref #49473 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50573/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50573/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50571',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50571/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50571/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50571/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50571',
#   'id': 1519643087,
#   'node_id': 'PR_kwDOAA0YD85GqUrr',
#   'number': 50571,
#   'title': 'TYP: Better numeric test types',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-04T22:07:27Z',
#   'updated_at': '2023-01-04T23:47:54Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50571',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50571',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50571.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50571.patch',
#    'merged_at': None},
#   'body': 'Currently we have that:\r\n* UNSIGNED_INT_NUMPY_DTYPES\r\n* SIGNED_INT_NUMPY_DTYPES\r\n* ALL_INT_NUMPY_DTYPES\r\n\r\nhave dtype `list[Dtype]`. This is a too broad dtype, and the better dtype for these objects is `list[NpDtype]`.\r\n\r\nExtracted from newest version of #49560.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50571/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50571/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50564',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50564/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50564/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50564/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50564',
#   'id': 1519514273,
#   'node_id': 'I_kwDOAA0YD85akfKh',
#   'number': 50564,
#   'title': 'BUG: when pd.nanops.nansum delegates to numpy.sum(), nans no longer treated as zeroes',
#   'user': {'login': 'MichaelTiemannOSC',
#    'id': 72577720,
#    'node_id': 'MDQ6VXNlcjcyNTc3NzIw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72577720?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MichaelTiemannOSC',
#    'html_url': 'https://github.com/MichaelTiemannOSC',
#    'followers_url': 'https://api.github.com/users/MichaelTiemannOSC/followers',
#    'following_url': 'https://api.github.com/users/MichaelTiemannOSC/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MichaelTiemannOSC/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MichaelTiemannOSC/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MichaelTiemannOSC/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MichaelTiemannOSC/orgs',
#    'repos_url': 'https://api.github.com/users/MichaelTiemannOSC/repos',
#    'events_url': 'https://api.github.com/users/MichaelTiemannOSC/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MichaelTiemannOSC/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-04T20:10:11Z',
#   'updated_at': '2023-01-04T20:10:11Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport numpy as np\r\nimport uncertainties as un\r\nfrom uncertainties import unumpy as unp\r\nimport pandas as pd\r\nimport pint\r\nimport pint_pandas\r\n\r\nfrom pint import Quantity as Q_\r\nfrom pint_pandas import PintArray as PA_\r\nfrom uncertainties import ufloat\r\n\r\nudata = [ufloat(1.2, .3), ufloat(np.nan, 0), ufloat(4.5, .6)]\r\n\r\nprint(f"uncertainties input data: {udata}")\r\nprint(f"sum({udata}) = {sum(udata)}")\r\n\r\nser = pd.Series(PA_(unp.nominal_values(udata),\r\n                    dtype=\'m\'))\r\nprint("float64 series with NaNs sums to non-NaN result")\r\nprint(ser)\r\nprint(ser.sum())\r\n\r\nprint("uncertainties series with NaNs should sum to non-NaN result")\r\nuser = pd.Series(PA_(udata, dtype=\'m\'))\r\nprint(user)\r\nprint(user.sum())\r\n\r\nprint("uncertainties series filling NaNs with zeros sums to non-NaN and expected result")\r\nprint(user.fillna(0))\r\nprint(user.fillna(0).sum())\n```\n\n\n### Issue Description\n\nThe `sum` function in Pandas treats NaN values as zero.  Extension arrays honor this, delegating "sum" to nanops.nansum and giving the extension array implementor the opportunity to follow that pattern.  When I use uncertainties (which wrap numpy functions) inside Pint Extension arrays (which implement nanops), wires get crossed and `sum` doesn\'t work as expected.  The problem is actually here, where pandas...:\r\n```\r\npandas/core/nanops.py(631)nansum()\r\n-> the_sum = values.sum(axis, dtype=dtype_sum)\r\n```\r\ncalls to numpy...:\r\n```\r\nnumpy/core/_methods.py(48)_sum()\r\n-> return umr_sum(a, axis, dtype, out, keepdims, initial, where)\r\n```\r\nwhich takes what uncertainties told it to do FOR THE SUM FUNCTION, not for nansum:\r\n```\r\nuncertainties/core.py(659)f_with_affine_output()\r\n-> pos_w_uncert = [index for (index, value) in enumerate(args)\r\n```\r\n\r\nPerhaps Pandas is to blame for calling values.sum instead of values.nansum?\n\n### Expected Behavior\n\nI expect that pandas nansum would delegate to numpy nansum, not numpy\'s sum.\n\n### Installed Versions\n\n<details>\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 8dab54d6573f7186ff0c3b6364d5e4dd635ff3e7\r\npython           : 3.9.13.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 21.6.0\r\nVersion          : Darwin Kernel Version 21.6.0: Thu Sep 29 20:12:57 PDT 2022; root:xnu-8020.240.7~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.2\r\nnumpy            : 1.23.4\r\npytz             : 2022.7\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.6.3\r\npip              : 22.3.1\r\nCython           : 0.29.32\r\npytest           : 7.2.0\r\nhypothesis       : 6.56.3\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.7.0\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : None\r\nbrotli           : \r\nfastparquet      : 0.8.3\r\nfsspec           : 2022.11.0\r\ngcsfs            : None\r\nmatplotlib       : 3.6.1\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : 2.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50564/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50564/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50560',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50560/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50560/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50560/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50560',
#   'id': 1519287041,
#   'node_id': 'PR_kwDOAA0YD85GpGqW',
#   'number': 50560,
#   'title': '(wait til 2.0) STYLE rename fixtures and enable redefined-outer-name on tests',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 106935113,
#     'node_id': 'MDU6TGFiZWwxMDY5MzUxMTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Code%20Style',
#     'name': 'Code Style',
#     'color': 'eb6420',
#     'default': False,
#     'description': 'Code style, linting, code_checks'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-04T16:48:55Z',
#   'updated_at': '2023-01-05T10:40:36Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50560',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50560',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50560.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50560.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #50553 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nThis changes a lot of files, but it's practically all automated\r\n\r\nI've split this into 2 separate commits:\r\n1. add the script / pre-commit hook, and run hook on all files\r\n2. make a handful of manual adjustments (for when a fixture is set equal to another one to generate a cartesian product)\r\n\r\nThe vast majority of changes here are automated and driven by the script (which is 100% tested)\r\n\r\nThis is what the pytest docs recommend doing https://docs.pytest.org/en/stable/reference/reference.html#pytest-fixture :\r\n\r\n> If a fixture is used in the same module in which it is defined, the function name of the fixture will be shadowed by the function arg that requests the fixture; one way to resolve this is to name the decorated function fixture_<fixturename> and then use @pytest.fixture(name='<fixturename>').",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50560/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50560/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
len(data)
# Out:
# 30

# %%
data[0]['user']
# Out:
# {'login': 'lithomas1',
#  'id': 47963215,
#  'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/lithomas1',
#  'html_url': 'https://github.com/lithomas1',
#  'followers_url': 'https://api.github.com/users/lithomas1/followers',
#  'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#  'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#  'repos_url': 'https://api.github.com/users/lithomas1/repos',
#  'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
data[0]['user']['id']
# Out:
# 47963215

# %%
max_iter = 10
for i in range(len(data)):
    print(data[i]['user']['id'])
    max_iter -= 1
    if max_iter == 0:
        break
# Out:
# 47963215
# 8078968
# 8078968
# 67752255
# 10647082
# 10647082
# 8078968
# 6319051
# 72577720
# 61934744

# %%
pd.DataFrame(data).head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                             html_url          id  \
# 0    https://github.com/pandas-dev/pandas/pull/50618  1523490755
# 1  https://github.com/pandas-dev/pandas/issues/50617  1523487004
# 2    https://github.com/pandas-dev/pandas/pull/50616  1523466294
# 3  https://github.com/pandas-dev/pandas/issues/50615  1523413757
# 4    https://github.com/pandas-dev/pandas/pull/50614  1523380130
#
#                node_id  number  \
# 0  PR_kwDOAA0YD85G3e2T   50618
# 1   I_kwDOAA0YD85azpEc   50617
# 2  PR_kwDOAA0YD85G3ZU-   50616
# 3   I_kwDOAA0YD85azXL9   50615
# 4  PR_kwDOAA0YD85G3HKC   50614
#
#                                                title  ... closed_at  \
# 0                                   WIP: CoW Replace  ...      None
# 1       DEPR: Series.__getitem__, Series.__setitem__  ...      None
# 2                               ENH: DTI/TDI as_unit  ...      None
# 3  BUG: Custom `__repr__` method not used when pr...  ...      None
# 4  CLN/BUG: Allow assert_produces_warning to rais...  ...      None
#
#   author_association active_lock_reason  draft  \
# 0             MEMBER               None   True
# 1             MEMBER               None    NaN
# 2             MEMBER               None  False
# 3               NONE               None    NaN
# 4             MEMBER               None  False
#
#                                         pull_request  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1                                                NaN
# 2  {'url': 'https://api.github.com/repos/pandas-d...
# 3                                                NaN
# 4  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                                 body  \
# 0  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 1  Trying to guess whether e.g. `ser[2]`, `ser[:2...
# 2  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 3  ### Pandas version checks\n\n- [X] I have chec...
# 4  Fixes this case that would not raise an `Asser...
#
#                                            reactions  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1  {'url': 'https://api.github.com/repos/pandas-d...
# 2  {'url': 'https://api.github.com/repos/pandas-d...
# 3  {'url': 'https://api.github.com/repos/pandas-d...
# 4  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                         timeline_url performed_via_github_app  \
# 0  https://api.github.com/repos/pandas-dev/pandas...                     None
# 1  https://api.github.com/repos/pandas-dev/pandas...                     None
# 2  https://api.github.com/repos/pandas-dev/pandas...                     None
# 3  https://api.github.com/repos/pandas-dev/pandas...                     None
# 4  https://api.github.com/repos/pandas-dev/pandas...                     None
#
#   state_reason
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#
# [5 rows x 30 columns]

# %%
pd.DataFrame(data, columns = ['url', 'repository_url', 'labels_url'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...

# %%
pd.DataFrame(data, columns = ['url', 'repository_url', 'labels_url', 'user'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                  user
# 0   {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 1   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 2   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 3   {'login': 'dasistkeintest', 'id': 67752255, 'n...
# 4   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 5   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 6   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 7   {'login': 'abonte', 'id': 6319051, 'node_id': ...
# 8   {'login': 'MichaelTiemannOSC', 'id': 72577720,...
# 9   {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 10  {'login': 'stev-0', 'id': 1316871, 'node_id': ...
# 11  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 12  {'login': 'lbittarello', 'id': 15511539, 'node...
# 13  {'login': 'bigtonylewis', 'id': 1799409, 'node...
# 14  {'login': 'dicristina', 'id': 74217512, 'node_...
# 15  {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 16  {'login': 'Elvislim1991', 'id': 41995978, 'nod...
# 17  {'login': 'adriantre', 'id': 11158599, 'node_i...
# 18  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 19  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 20  {'login': 'mfortin-adata', 'id': 90690099, 'no...
# 21  {'login': 'clbarnes', 'id': 8995328, 'node_id'...
# 22  {'login': 'kostyafarber', 'id': 73378227, 'nod...
# 23  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 24  {'login': 'datapythonista', 'id': 10058240, 'n...
# 25  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 26  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 27  {'login': 'topper-123', 'id': 26364415, 'node_...
# 28  {'login': 'MichaelTiemannOSC', 'id': 72577720,...
# 29  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...

# %%
temp_file = pd.DataFrame(data, columns = ['url', 'repository_url', 'labels_url', 'user'])
temp_file.to_csv('data/sample-csv/0227_json_ex.csv')

# %%
def toSeries(x):
    return pd.Series(x)

print(temp_file.shape)

df_temp = temp_file['user']
# old way
# df_temp = temp_file['user'].apply(pd.Series)

# custom way
df_temp = temp_file['user'].apply(lambda x : toSeries(x))
temp_file = temp_file.join(df_temp,lsuffix="_left", rsuffix="_right")
print(temp_file.shape)
temp_file.drop(['user'], axis=1, inplace=True)

temp_file.head(10)
# Out:
# (30, 4)
# (30, 22)
#                                             url_left  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
# 5  https://api.github.com/repos/pandas-dev/pandas...
# 6  https://api.github.com/repos/pandas-dev/pandas...
# 7  https://api.github.com/repos/pandas-dev/pandas...
# 8  https://api.github.com/repos/pandas-dev/pandas...
# 9  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
# 5  https://api.github.com/repos/pandas-dev/pandas
# 6  https://api.github.com/repos/pandas-dev/pandas
# 7  https://api.github.com/repos/pandas-dev/pandas
# 8  https://api.github.com/repos/pandas-dev/pandas
# 9  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url              login  \
# 0  https://api.github.com/repos/pandas-dev/pandas...          lithomas1
# 1  https://api.github.com/repos/pandas-dev/pandas...       jbrockmendel
# 2  https://api.github.com/repos/pandas-dev/pandas...       jbrockmendel
# 3  https://api.github.com/repos/pandas-dev/pandas...     dasistkeintest
# 4  https://api.github.com/repos/pandas-dev/pandas...          mroeschke
# 5  https://api.github.com/repos/pandas-dev/pandas...          mroeschke
# 6  https://api.github.com/repos/pandas-dev/pandas...       jbrockmendel
# 7  https://api.github.com/repos/pandas-dev/pandas...             abonte
# 8  https://api.github.com/repos/pandas-dev/pandas...  MichaelTiemannOSC
# 9  https://api.github.com/repos/pandas-dev/pandas...              phofl
#
#          id               node_id  \
# 0  47963215  MDQ6VXNlcjQ3OTYzMjE1
# 1   8078968  MDQ6VXNlcjgwNzg5Njg=
# 2   8078968  MDQ6VXNlcjgwNzg5Njg=
# 3  67752255  MDQ6VXNlcjY3NzUyMjU1
# 4  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 5  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 6   8078968  MDQ6VXNlcjgwNzg5Njg=
# 7   6319051  MDQ6VXNlcjYzMTkwNTE=
# 8  72577720  MDQ6VXNlcjcyNTc3NzIw
# 9  61934744  MDQ6VXNlcjYxOTM0NzQ0
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/479632...
# 1  https://avatars.githubusercontent.com/u/807896...
# 2  https://avatars.githubusercontent.com/u/807896...
# 3  https://avatars.githubusercontent.com/u/677522...
# 4  https://avatars.githubusercontent.com/u/106470...
# 5  https://avatars.githubusercontent.com/u/106470...
# 6  https://avatars.githubusercontent.com/u/807896...
# 7  https://avatars.githubusercontent.com/u/631905...
# 8  https://avatars.githubusercontent.com/u/725777...
# 9  https://avatars.githubusercontent.com/u/619347...
#
#                                         url_right  \
# 0          https://api.github.com/users/lithomas1
# 1       https://api.github.com/users/jbrockmendel
# 2       https://api.github.com/users/jbrockmendel
# 3     https://api.github.com/users/dasistkeintest
# 4          https://api.github.com/users/mroeschke
# 5          https://api.github.com/users/mroeschke
# 6       https://api.github.com/users/jbrockmendel
# 7             https://api.github.com/users/abonte
# 8  https://api.github.com/users/MichaelTiemannOSC
# 9              https://api.github.com/users/phofl
#
#                                html_url  ...  \
# 0          https://github.com/lithomas1  ...
# 1       https://github.com/jbrockmendel  ...
# 2       https://github.com/jbrockmendel  ...
# 3     https://github.com/dasistkeintest  ...
# 4          https://github.com/mroeschke  ...
# 5          https://github.com/mroeschke  ...
# 6       https://github.com/jbrockmendel  ...
# 7             https://github.com/abonte  ...
# 8  https://github.com/MichaelTiemannOSC  ...
# 9              https://github.com/phofl  ...
#
#                                        following_url  \
# 0  https://api.github.com/users/lithomas1/followi...
# 1  https://api.github.com/users/jbrockmendel/foll...
# 2  https://api.github.com/users/jbrockmendel/foll...
# 3  https://api.github.com/users/dasistkeintest/fo...
# 4  https://api.github.com/users/mroeschke/followi...
# 5  https://api.github.com/users/mroeschke/followi...
# 6  https://api.github.com/users/jbrockmendel/foll...
# 7  https://api.github.com/users/abonte/following{...
# 8  https://api.github.com/users/MichaelTiemannOSC...
# 9  https://api.github.com/users/phofl/following{/...
#
#                                            gists_url  \
# 0  https://api.github.com/users/lithomas1/gists{/...
# 1  https://api.github.com/users/jbrockmendel/gist...
# 2  https://api.github.com/users/jbrockmendel/gist...
# 3  https://api.github.com/users/dasistkeintest/gi...
# 4  https://api.github.com/users/mroeschke/gists{/...
# 5  https://api.github.com/users/mroeschke/gists{/...
# 6  https://api.github.com/users/jbrockmendel/gist...
# 7  https://api.github.com/users/abonte/gists{/gis...
# 8  https://api.github.com/users/MichaelTiemannOSC...
# 9  https://api.github.com/users/phofl/gists{/gist...
#
#                                          starred_url  \
# 0  https://api.github.com/users/lithomas1/starred...
# 1  https://api.github.com/users/jbrockmendel/star...
# 2  https://api.github.com/users/jbrockmendel/star...
# 3  https://api.github.com/users/dasistkeintest/st...
# 4  https://api.github.com/users/mroeschke/starred...
# 5  https://api.github.com/users/mroeschke/starred...
# 6  https://api.github.com/users/jbrockmendel/star...
# 7  https://api.github.com/users/abonte/starred{/o...
# 8  https://api.github.com/users/MichaelTiemannOSC...
# 9  https://api.github.com/users/phofl/starred{/ow...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/lithomas1/subscri...
# 1  https://api.github.com/users/jbrockmendel/subs...
# 2  https://api.github.com/users/jbrockmendel/subs...
# 3  https://api.github.com/users/dasistkeintest/su...
# 4  https://api.github.com/users/mroeschke/subscri...
# 5  https://api.github.com/users/mroeschke/subscri...
# 6  https://api.github.com/users/jbrockmendel/subs...
# 7  https://api.github.com/users/abonte/subscriptions
# 8  https://api.github.com/users/MichaelTiemannOSC...
# 9   https://api.github.com/users/phofl/subscriptions
#
#                                    organizations_url  \
# 0        https://api.github.com/users/lithomas1/orgs
# 1     https://api.github.com/users/jbrockmendel/orgs
# 2     https://api.github.com/users/jbrockmendel/orgs
# 3   https://api.github.com/users/dasistkeintest/orgs
# 4        https://api.github.com/users/mroeschke/orgs
# 5        https://api.github.com/users/mroeschke/orgs
# 6     https://api.github.com/users/jbrockmendel/orgs
# 7           https://api.github.com/users/abonte/orgs
# 8  https://api.github.com/users/MichaelTiemannOSC...
# 9            https://api.github.com/users/phofl/orgs
#
#                                            repos_url  \
# 0       https://api.github.com/users/lithomas1/repos
# 1    https://api.github.com/users/jbrockmendel/repos
# 2    https://api.github.com/users/jbrockmendel/repos
# 3  https://api.github.com/users/dasistkeintest/repos
# 4       https://api.github.com/users/mroeschke/repos
# 5       https://api.github.com/users/mroeschke/repos
# 6    https://api.github.com/users/jbrockmendel/repos
# 7          https://api.github.com/users/abonte/repos
# 8  https://api.github.com/users/MichaelTiemannOSC...
# 9           https://api.github.com/users/phofl/repos
#
#                                           events_url  \
# 0  https://api.github.com/users/lithomas1/events{...
# 1  https://api.github.com/users/jbrockmendel/even...
# 2  https://api.github.com/users/jbrockmendel/even...
# 3  https://api.github.com/users/dasistkeintest/ev...
# 4  https://api.github.com/users/mroeschke/events{...
# 5  https://api.github.com/users/mroeschke/events{...
# 6  https://api.github.com/users/jbrockmendel/even...
# 7  https://api.github.com/users/abonte/events{/pr...
# 8  https://api.github.com/users/MichaelTiemannOSC...
# 9  https://api.github.com/users/phofl/events{/pri...
#
#                                  received_events_url  type site_admin
# 0  https://api.github.com/users/lithomas1/receive...  User      False
# 1  https://api.github.com/users/jbrockmendel/rece...  User      False
# 2  https://api.github.com/users/jbrockmendel/rece...  User      False
# 3  https://api.github.com/users/dasistkeintest/re...  User      False
# 4  https://api.github.com/users/mroeschke/receive...  User      False
# 5  https://api.github.com/users/mroeschke/receive...  User      False
# 6  https://api.github.com/users/jbrockmendel/rece...  User      False
# 7  https://api.github.com/users/abonte/received_e...  User      False
# 8  https://api.github.com/users/MichaelTiemannOSC...  User      False
# 9  https://api.github.com/users/phofl/received_ev...  User      False
#
# [10 rows x 21 columns]
