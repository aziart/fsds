# %% [markdown]
# ### Flight Price Prediction (EDA, Feature Engineering)

# %% [markdown]
# #### Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
trn = pd.read_excel("data/flight_price/train.xlsx")
tst = pd.read_excel("data/flight_price/test.xlsx")
display(trn.head(), trn.shape)
display(tst.head(), tst.shape)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
# (10683, 11)
#              Airline Date_of_Journey    Source Destination            Route  \
# ...

# %%
trn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
trn['Date_of_Journey'].str.split('/').str[0]
# Out:
# 0        24
# 1         1
# 2         9
# 3        12
# 4        01
#          ..
# 10678     9
# 10679    27
# 10680    27
# 10681    01
# 10682     9
# Name: Date_of_Journey, Length: 10683, dtype: object

# %%
trn['Journey_Date'] = trn['Date_of_Journey'].str.split('/').str[0]
trn['Journey_Month'] = trn['Date_of_Journey'].str.split('/').str[1]
trn['Journey_Year'] = trn['Date_of_Journey'].str.split('/').str[2]
display(trn.head())
trn.info()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#   Journey_Date Journey_Month Journey_Year
# 0           24            03         2019
# ...

# %%
trn['Journey_Date'] = trn['Journey_Date'].astype(int)
trn['Journey_Month'] = trn['Journey_Month'].astype(int)
trn['Journey_Year'] = trn['Journey_Year'].astype(int)
display(trn.head())
trn[['Journey_Date', 'Journey_Month', 'Journey_Year']].info()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    Journey_Date  Journey_Month  Journey_Year
# 0            24              3          2019
# ...

# %%
trn.drop('Date_of_Journey', axis=1, inplace=True)
display(trn.columns)
# Out:
# Index(['Airline', 'Source', 'Destination', 'Route', 'Dep_Time', 'Arrival_Time',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'Journey_Date',
#        'Journey_Month', 'Journey_Year'],
#       dtype='object')

# %%
trn.head(2) # note: arrival time
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Journey_Date  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897            24
# 1         13:15   7h 25m     2 stops         No info   7662             1
#
#    Journey_Month  Journey_Year
# 0              3          2019
# 1              5          2019

# %%
trn['Arrival_Time'] = trn['Arrival_Time'].str.split(' ').str[0]
# trn['Arrival_Time'] = trn['Arrival_Time'].apply(lambda x: x.split(' ')[0])
trn['Arrival_Hour'] = trn['Arrival_Time'].str.split(':').str[0]
trn['Arrival_Minute'] = trn['Arrival_Time'].str.split(':').str[1]
display(trn.head(2))
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#   Arrival_Time Duration Total_Stops Additional_Info  Price  Journey_Date  \
# 0        01:10   2h 50m    non-stop         No info   3897            24
# 1        13:15   7h 25m     2 stops         No info   7662             1
#
#    Journey_Month  Journey_Year Arrival_Hour Arrival_Minute
# 0              3          2019           01             10
# 1              5          2019           13             15

# %%
display(trn[['Arrival_Hour', 'Arrival_Minute']].dtypes)
trn['Arrival_Hour'] = trn['Arrival_Hour'].astype(int)
trn['Arrival_Minute'] = trn['Arrival_Minute'].astype(int)
display(trn[['Arrival_Hour', 'Arrival_Minute']].dtypes)
# Out:
# Arrival_Hour      object
# Arrival_Minute    object
# dtype: object
# Arrival_Hour      int64
# Arrival_Minute    int64
# dtype: object

# %%
trn['Dep_Hour'] = trn['Dep_Time'].str.split(':').str[0]
trn['Dep_Minute'] = trn['Dep_Time'].str.split(':').str[1]
display(trn.head(2))
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#   Arrival_Time Duration Total_Stops Additional_Info  Price  Journey_Date  \
# 0        01:10   2h 50m    non-stop         No info   3897            24
# 1        13:15   7h 25m     2 stops         No info   7662             1
#
#    Journey_Month  Journey_Year  Arrival_Hour  Arrival_Minute Dep_Hour  \
# 0              3          2019             1              10       22
# 1              5          2019            13              15       05
#
#   Dep_Minute
# 0         20
# 1         50

# %%
display(trn[['Dep_Hour', 'Dep_Minute']].dtypes)
trn['Dep_Hour'] = trn['Dep_Hour'].astype(int)
trn['Dep_Minute'] = trn['Dep_Minute'].astype(int)
display(trn[['Dep_Hour', 'Dep_Minute']].dtypes)
# Out:
# Dep_Hour      object
# Dep_Minute    object
# dtype: object
# Dep_Hour      int64
# Dep_Minute    int64
# dtype: object

# %%
trn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Route            10682 non-null  object
#  4   Dep_Time         10683 non-null  object
#  5   Arrival_Time     10683 non-null  object
#  6   Duration         10683 non-null  object
#  7   Total_Stops      10682 non-null  object
#  8   Additional_Info  10683 non-null  object
#  9   Price            10683 non-null  int64
#  10  Journey_Date     10683 non-null  int64
#  11  Journey_Month    10683 non-null  int64
#  12  Journey_Year     10683 non-null  int64
#  13  Arrival_Hour     10683 non-null  int64
#  14  Arrival_Minute   10683 non-null  int64
#  15  Dep_Hour         10683 non-null  int64
#  16  Dep_Minute       10683 non-null  int64
# ...

# %%
trn['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
trn['Total_Stops'] = trn['Total_Stops'].map({'non-stop': 0, '1 stop': 1, '2 stops': 2, '3 stops': 3, '4 stops': 4, 'nan': 1})
trn['Total_Stops'].value_counts()
# Out:
# 1.0    5625
# 0.0    3491
# 2.0    1520
# 3.0      45
# 4.0       1
# Name: Total_Stops, dtype: int64

# %%
trn.drop('Route', axis=1, inplace=True)
display(trn.head())
# Out:
#        Airline    Source Destination Dep_Time Arrival_Time Duration  \
# 0       IndiGo  Banglore   New Delhi    22:20        01:10   2h 50m
# 1    Air India   Kolkata    Banglore    05:50        13:15   7h 25m
# 2  Jet Airways     Delhi      Cochin    09:25        04:25      19h
# 3       IndiGo   Kolkata    Banglore    18:05        23:30   5h 25m
# 4       IndiGo  Banglore   New Delhi    16:50        21:35   4h 45m
#
#    Total_Stops Additional_Info  Price  Journey_Date  Journey_Month  \
# 0          0.0         No info   3897            24              3
# 1          2.0         No info   7662             1              5
# 2          2.0         No info  13882             9              6
# 3          1.0         No info   6218            12              5
# 4          1.0         No info  13302             1              3
#
#    Journey_Year  Arrival_Hour  Arrival_Minute  Dep_Hour  Dep_Minute
# 0          2019             1              10        22          20
# ...

# %%
display(trn['Airline'].unique())
display(trn['Airline'].value_counts())
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
display(trn['Source'].unique())
display(trn['Source'].value_counts())
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %%
display(trn['Destination'].unique())
display(trn['Destination'].value_counts())
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %%
display(trn['Additional_Info'].unique())
display(trn['Additional_Info'].value_counts())
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %%
pd.get_dummies(trn, columns=['Airline', 'Source', 'Destination', 'Additional_Info'], drop_first=True)
# Out:
#       Dep_Time Arrival_Time Duration  Total_Stops  Price  Journey_Date  \
# 0        22:20        01:10   2h 50m          0.0   3897            24
# 1        05:50        13:15   7h 25m          2.0   7662             1
# 2        09:25        04:25      19h          2.0  13882             9
# 3        18:05        23:30   5h 25m          1.0   6218            12
# 4        16:50        21:35   4h 45m          1.0  13302             1
# ...        ...          ...      ...          ...    ...           ...
# 10678    19:55        22:25   2h 30m          0.0   4107             9
# 10679    20:45        23:20   2h 35m          0.0   4145            27
# 10680    08:20        11:20       3h          0.0   7229            27
# 10681    11:30        14:10   2h 40m          0.0  12648             1
# 10682    10:55        19:15   8h 20m          2.0  11753             9
#
#        Journey_Month  Journey_Year  Arrival_Hour  Arrival_Minute  Dep_Hour  \
# ...

# %%
trn = pd.get_dummies(trn, columns=['Airline', 'Source', 'Destination', 'Additional_Info'], drop_first=True)
display(trn)
# Out:
#       Dep_Time Arrival_Time Duration  Total_Stops  Price  Journey_Date  \
# 0        22:20        01:10   2h 50m          0.0   3897            24
# 1        05:50        13:15   7h 25m          2.0   7662             1
# 2        09:25        04:25      19h          2.0  13882             9
# 3        18:05        23:30   5h 25m          1.0   6218            12
# 4        16:50        21:35   4h 45m          1.0  13302             1
# ...        ...          ...      ...          ...    ...           ...
# 10678    19:55        22:25   2h 30m          0.0   4107             9
# 10679    20:45        23:20   2h 35m          0.0   4145            27
# 10680    08:20        11:20       3h          0.0   7229            27
# 10681    11:30        14:10   2h 40m          0.0  12648             1
# 10682    10:55        19:15   8h 20m          2.0  11753             9
#
#        Journey_Month  Journey_Year  Arrival_Hour  Arrival_Minute  Dep_Hour  \
# ...
