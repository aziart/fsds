# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Excel File

# %%
file = pd.ExcelFile('data/sales.xlsx')

# %%
file.sheet_names
# Out:
# ['SalesOrders']

# %%
data = file.parse('SalesOrders')
data.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2021-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2021-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2021-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2021-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2021-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %% [markdown]
# ### Header

# %%
data = file.parse('SalesOrders', header=None)
data.head()
# Out:
#                      0        1        2       3      4          5       6
# 0            OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 1  2021-01-06 00:00:00     East    Jones  Pencil     95       1.99  189.05
# 2  2021-01-23 00:00:00  Central   Kivell  Binder     50      19.99   999.5
# 3  2021-02-09 00:00:00  Central  Jardine  Pencil     36       4.99  179.64
# 4  2021-02-26 00:00:00  Central     Gill     Pen     27      19.99  539.73

# %% [markdown]
# We can also specify our own column names

# %%
data = file.parse('SalesOrders', header=None, names=['OD', 'RG', 'RP', 'ITM', 'UNT', 'UCST', 'TTL'])
data.head()
# Out:
#                     OD       RG       RP     ITM    UNT       UCST     TTL
# 0            OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 1  2021-01-06 00:00:00     East    Jones  Pencil     95       1.99  189.05
# 2  2021-01-23 00:00:00  Central   Kivell  Binder     50      19.99   999.5
# 3  2021-02-09 00:00:00  Central  Jardine  Pencil     36       4.99  179.64
# 4  2021-02-26 00:00:00  Central     Gill     Pen     27      19.99  539.73

# %%
data = file.parse('SalesOrders', names=['OD', 'RG', 'RP', 'ITM', 'UNT', 'UCST', 'TTL'])
data.head()
# Out:
#           OD       RG       RP     ITM  UNT   UCST     TTL
# 0 2021-01-06     East    Jones  Pencil   95   1.99  189.05
# 1 2021-01-23  Central   Kivell  Binder   50  19.99  999.50
# 2 2021-02-09  Central  Jardine  Pencil   36   4.99  179.64
# 3 2021-02-26  Central     Gill     Pen   27  19.99  539.73
# 4 2021-03-15     West  Sorvino  Pencil   56   2.99  167.44

# %%
data = file.parse('SalesOrders', names=['OD', 'RG', 'RP', 'ITM', 'UNT', 'UCST', 'TTL'])
data.head()
# Out:
#           OD       RG       RP     ITM  UNT   UCST     TTL
# 0 2021-01-06     East    Jones  Pencil   95   1.99  189.05
# 1 2021-01-23  Central   Kivell  Binder   50  19.99  999.50
# 2 2021-02-09  Central  Jardine  Pencil   36   4.99  179.64
# 3 2021-02-26  Central     Gill     Pen   27  19.99  539.73
# 4 2021-03-15     West  Sorvino  Pencil   56   2.99  167.44

# %%
data = pd.read_csv("data/sample-csv/addresses.csv")
data.head()
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
data = pd.read_csv("data/sample-csv/addresses.csv", names = ['ID', 'LOCID', 'ADR1', 'ADR2', 'CT', 'ST', 'PC', 'CNTR'])
data.head()
# Out:
#    ID        LOCID                   ADR1       ADR2            CT  \
# 0  id  location_id              address_1  address_2          city
# 1   1            1  2600 Middlefield Road        NaN  Redwood City
# 2   2            2       24 Second Avenue        NaN     San Mateo
# 3   3            3       24 Second Avenue        NaN     San Mateo
# 4   4            4       24 Second Avenue        NaN     San Mateo
#
#                ST           PC     CNTR
# 0  state_province  postal_code  country
# 1              CA        94063       US
# 2              CA        94401       US
# 3              CA        94403       US
# 4              CA        94401       US

# %%
data = pd.read_csv("data/sample-csv/addresses.csv", names = ['ID', 'LOCID', 'ADR1', 'ADR2', 'CT', 'ST', 'PC', 'CNTR', 'NaN_1', 'NaN_2'])
data.head()
# Out:
#    ID        LOCID                   ADR1       ADR2            CT  \
# 0  id  location_id              address_1  address_2          city
# 1   1            1  2600 Middlefield Road        NaN  Redwood City
# 2   2            2       24 Second Avenue        NaN     San Mateo
# 3   3            3       24 Second Avenue        NaN     San Mateo
# 4   4            4       24 Second Avenue        NaN     San Mateo
#
#                ST           PC     CNTR  NaN_1  NaN_2
# 0  state_province  postal_code  country    NaN    NaN
# 1              CA        94063       US    NaN    NaN
# 2              CA        94401       US    NaN    NaN
# 3              CA        94403       US    NaN    NaN
# 4              CA        94401       US    NaN    NaN

# %%
data = pd.read_csv("data/sample-csv/addresses.csv", names = ['ADR1', 'ADR2', 'CT', 'ST', 'PC', 'CNTR'])
data.head()
# Out:
#                                  ADR1       ADR2            CT  \
# id location_id              address_1  address_2          city
# 1  1            2600 Middlefield Road        NaN  Redwood City
# 2  2                 24 Second Avenue        NaN     San Mateo
# 3  3                 24 Second Avenue        NaN     San Mateo
# 4  4                 24 Second Avenue        NaN     San Mateo
#
#                             ST           PC     CNTR
# id location_id  state_province  postal_code  country
# 1  1                        CA        94063       US
# 2  2                        CA        94401       US
# 3  3                        CA        94403       US
# 4  4                        CA        94401       US

# %% [markdown]
# ### Delimiter argument
# In this specific example, the file records are separated by comma, but there can be csv files separated by other symbols. So, we can use delimiter argument and specify it explicitly

# %%
data = pd.read_csv("data/sample-csv/addresses.csv", delimiter=',')
data.head()
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %% [markdown]
# ### skip rows

# %%
data = pd.read_csv("data/sample-csv/addresses.csv", skiprows=[1,2,3])
data.head()
# Out:
#    id  location_id          address_1 address_2        city state_province  \
# 0   4            4   24 Second Avenue       NaN   San Mateo             CA
# 1   5            5   24 Second Avenue       NaN   San Mateo             CA
# 2   6            6  800 Middle Avenue       NaN  Menlo Park             CA
# 3   7            7     500 Arbor Road       NaN  Menlo Park             CA
# 4   8            8  800 Middle Avenue       NaN  Menlo Park             CA
#
#   postal_code country
# 0       94401      US
# 1       94401      US
# 2  94025-9881      US
# 3       94025      US
# 4  94025-9881      US

# %%
data = pd.read_csv("data/sample-csv/addresses.csv", skiprows=[0,2,3])
data.head()
# Out:
#    1  1.1 2600 Middlefield Road Unnamed: 3 Redwood City  CA       94063  US
# 0  4    4      24 Second Avenue        NaN    San Mateo  CA       94401  US
# 1  5    5      24 Second Avenue        NaN    San Mateo  CA       94401  US
# 2  6    6     800 Middle Avenue        NaN   Menlo Park  CA  94025-9881  US
# 3  7    7        500 Arbor Road        NaN   Menlo Park  CA       94025  US
# 4  8    8     800 Middle Avenue        NaN   Menlo Park  CA  94025-9881  US

# %%
df = pd.read_csv("data/sample-csv/services.csv")
df.head(3)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
# 2        Resident of San Mateo County age 55 or over   NaN  ...
#
#   interpretation_services                                           keywords  \
# 0                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 1                     NaN  EMPLOYMENT/TRAINING SERVICES, Job Development,...
# 2                     NaN  Geriatric Counseling, Older Adults, Gay, Lesbi...
#
#   languages                              name required_documents  \
# 0       NaN   Fair Oaks Adult Activity Center                NaN
# 1       NaN  Second Career Employment Program                NaN
# 2       NaN            Senior Peer Counseling                NaN
#
#       service_areas  status wait_time website taxonomy_ids
# 0             Colma  active  No wait.     NaN          NaN
# 1  San Mateo County  active   Varies.     NaN          NaN
# 2  San Mateo County  active   Varies.     NaN          NaN
#
# [3 rows x 22 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Datatypes of columns

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df.tail(2)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# 22  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...        None
#
#                     email  ...  \
# 21  passports@example.org  ...
# 22                    NaN  ...
#
#                               interpretation_services  \
# 21  We offer 3-way interpretation services over th...
# 22                                                NaN
#
#                                       keywords languages  \
# 21                             Salud, Medicina   Spanish
# 22  Ruby on Rails/Postgres/Redis, testing, wic       NaN
#
#                     name                        required_documents  \
# 21       Passport Photos  Government-issued picture identification
# 22  Example Service Name                                       NaN
#
#                        service_areas  status            wait_time  \
# 21  Alameda County, San Mateo County  active  No wait to 2 weeks.
# 22  San Mateo County, Alameda County  active   No wait to 2 weeks
#
#                    website                              taxonomy_ids
# 21  http://www.example.com  105, 108, 108-05, 108-05-01, 111, 111-05
# 22  http://www.example.com                                       NaN
#
# [2 rows x 22 columns]

# %% [markdown]
# ### Columns

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %% [markdown]
# ### Selecting columns

# %%
df['id'].head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: id, dtype: int64

# %%
a = df['id'].head()
type(a)
# Out:
# pandas.core.series.Series

# %%
df[['id']].head()
# Out:
#    id
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5

# %%
a = df[['id']].head()
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['id', 'email']].head()
# Out:
#    id email
# 0   1   NaN
# 1   2   NaN
# 2   3   NaN
# 3   4   NaN
# 4   5   NaN

# %%
a = df[['id', 'email']].head()
type(a)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# In pandas it is possible to access data from internet directly. For example, csv files by providing URL into read_csv arguments.
