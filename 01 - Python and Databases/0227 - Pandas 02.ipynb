# %%
import pandas as pd

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0].head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df = df[0]

# %%
df.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df.dtypes.head()
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# dtype: object

# %%
df[['ORB', 'DRB', 'TRB', 'AST',	'STL']].head()
# Out:
#    ORB  DRB  TRB  AST STL
# 0   79  222  301   68  27
# 1    9   19   28   16  16
# 2  199  324  523   66  38
# 3   23   54   77   15   4
# 4   27  220  247  129  41

# %%
df.to_csv('data/sample-csv/0227_NBA.csv', index=False)

# %%
d = """
{
    "name": "John Doe",
    "email": "John.Doe@company.com",
    "tech": ["ML", "DL", "CV", "NLP", "RL", "BD", "DA"],
    "platform": ["techneuron", "kidsneuron", "ineuron"]
}
"""

# %%
type(d)
# Out:
# str

# %%
import json

# %%
result = json.loads(d)

# %%
result
# Out:
# {'name': 'John Doe',
#  'email': 'John.Doe@company.com',
#  'tech': ['ML', 'DL', 'CV', 'NLP', 'RL', 'BD', 'DA'],
#  'platform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
type(result)
# Out:
# dict

# %%
d = """
{
    "name": "John Doe",
    "email": "John.Doe@company.com",
    "tech": ["ML", "DL", "CV"],
    "platform": ["techneuron", "kidsneuron", "ineuron"]
}
"""

# %%
result = json.loads(d)

# %%
pd.DataFrame(result)
# Out:
#        name                 email tech    platform
# 0  John Doe  John.Doe@company.com   ML  techneuron
# 1  John Doe  John.Doe@company.com   DL  kidsneuron
# 2  John Doe  John.Doe@company.com   CV     ineuron

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url).head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                             html_url          id  \
# 0    https://github.com/pandas-dev/pandas/pull/50400  1508254094
# 1  https://github.com/pandas-dev/pandas/issues/50399  1508214211
# 2    https://github.com/pandas-dev/pandas/pull/50398  1508195560
# 3    https://github.com/pandas-dev/pandas/pull/50397  1508193487
# 4    https://github.com/pandas-dev/pandas/pull/50396  1508154861
#
#                node_id  number  \
# 0  PR_kwDOAA0YD85GD9HI   50400
# 1   I_kwDOAA0YD85Z5YXD   50399
# 2  PR_kwDOAA0YD85GDvwX   50398
# 3  PR_kwDOAA0YD85GDvSA   50397
# 4  PR_kwDOAA0YD85GDmxd   50396
#
#                                                title  ... closed_at  \
# 0  BUG: Index with null value not serialized corr...  ...       NaT
# 1       BUG: Rolling.mean downcasts extension dtypes  ...       NaT
# 2  ENH: add math mode to formatter escape="latex-...  ...       NaT
# 3  STYLE pre-commit check to ensure that test fun...  ...       NaT
# 4  BUG/COMPAT: fix assert_* functions for nested ...  ...       NaT
#
#   author_association active_lock_reason  draft  \
# 0             MEMBER                NaN    1.0
# 1               NONE                NaN    NaN
# 2        CONTRIBUTOR                NaN    0.0
# 3             MEMBER                NaN    0.0
# 4             MEMBER                NaN    0.0
#
#                                         pull_request  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1                                                NaN
# 2  {'url': 'https://api.github.com/repos/pandas-d...
# 3  {'url': 'https://api.github.com/repos/pandas-d...
# 4  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                                 body  \
# 0  - [ ] closes #31801 (Replace xxxx with the Git...
# 1  ### Pandas version checks\n\n- [X] I have chec...
# 2  - [x] closes #50040\r\n- [x] All [code checks ...
# 3  - [ ] closes #50379 (Replace xxxx with the Git...
# 4  This adds tests for `assert_almost_equal` (use...
#
#                                            reactions  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1  {'url': 'https://api.github.com/repos/pandas-d...
# 2  {'url': 'https://api.github.com/repos/pandas-d...
# 3  {'url': 'https://api.github.com/repos/pandas-d...
# 4  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                         timeline_url performed_via_github_app  \
# 0  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 1  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 2  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 3  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 4  https://api.github.com/repos/pandas-dev/pandas...                      NaN
#
#   state_reason
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 30 columns]

# %%
import requests

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
type(data)
# Out:
# requests.models.Response

# %%
data = data.json()

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50400',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50400/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50400/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50400/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50400',
#   'id': 1508254094,
#   'node_id': 'PR_kwDOAA0YD85GD9HI',
#   'number': 50400,
#   'title': 'BUG: Index with null value not serialized correctly to json',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-22T17:12:54Z',
#   'updated_at': '2022-12-22T17:14:25Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50400',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50400',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50400.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50400.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #31801 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nRestores 0.25.3 behavior, which honestly feels a little weird to me, since it doesn't roundtrip. I'm not too familiar with JSON format, though (I guess the problem is that null can't be a key?).\r\n\r\nAlso serialize decimal nans correctly.\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50400/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50400/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50399',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50399/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50399/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50399/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50399',
#   'id': 1508214211,
#   'node_id': 'I_kwDOAA0YD85Z5YXD',
#   'number': 50399,
#   'title': 'BUG: Rolling.mean downcasts extension dtypes',
#   'user': {'login': 'bollard',
#    'id': 358225,
#    'node_id': 'MDQ6VXNlcjM1ODIyNQ==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/358225?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bollard',
#    'html_url': 'https://github.com/bollard',
#    'followers_url': 'https://api.github.com/users/bollard/followers',
#    'following_url': 'https://api.github.com/users/bollard/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bollard/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/bollard/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bollard/subscriptions',
#    'organizations_url': 'https://api.github.com/users/bollard/orgs',
#    'repos_url': 'https://api.github.com/users/bollard/repos',
#    'events_url': 'https://api.github.com/users/bollard/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/bollard/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-22T16:52:46Z',
#   'updated_at': '2022-12-22T16:52:46Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\nser = pd.Series([i / 10 for i in range(1, 20)]).astype(pd.Float64Dtype())\r\nser.rolling(2).mean().dtype # dtype('float64')\n```\n\n\n### Issue Description\n\n`#Rolling.mean` prematurely downcast from extension-array type dtypes\n\n### Expected Behavior\n\nThat (in this example) the `Float64Dtype` is preserved\n\n### Installed Versions\n\n<details>\r\n\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 8dab54d6573f7186ff0c3b6364d5e4dd635ff3e7\r\npython           : 3.10.8.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19044\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 165 Stepping 3, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : en_US.UTF-8\r\nLANG             : en_US.UTF-8\r\nLOCALE           : English_United Kingdom.1252\r\n\r\npandas           : 1.5.2\r\nnumpy            : 1.23.4\r\npytz             : 2022.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.5.0\r\npip              : 22.2.2\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.9.1\r\nhtml5lib         : None\r\npymysql          : 1.0.2\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.6.0\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : None\r\nbrotli           : \r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.5.3\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : 9.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : 1.4.39\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n\r\n</details>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50399/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50399/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50398',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50398/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50398/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50398/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50398',
#   'id': 1508195560,
#   'node_id': 'PR_kwDOAA0YD85GDvwX',
#   'number': 50398,
#   'title': 'ENH: add math mode to formatter escape="latex-math"',
#   'user': {'login': 'natmokval',
#    'id': 91160475,
#    'node_id': 'MDQ6VXNlcjkxMTYwNDc1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91160475?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/natmokval',
#    'html_url': 'https://github.com/natmokval',
#    'followers_url': 'https://api.github.com/users/natmokval/followers',
#    'following_url': 'https://api.github.com/users/natmokval/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/natmokval/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/natmokval/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/natmokval/subscriptions',
#    'organizations_url': 'https://api.github.com/users/natmokval/orgs',
#    'repos_url': 'https://api.github.com/users/natmokval/repos',
#    'events_url': 'https://api.github.com/users/natmokval/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/natmokval/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-22T16:43:20Z',
#   'updated_at': '2022-12-22T16:43:20Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50398',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50398',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50398.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50398.patch',
#    'merged_at': None},
#   'body': '- [x] closes #50040\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n \r\nAdded `latex-math` option to `_str_escape` to avoid escaping `$`, `\\[` and `\\]`.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50398/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50398/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50397',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50397/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50397/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50397/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50397',
#   'id': 1508193487,
#   'node_id': 'PR_kwDOAA0YD85GDvSA',
#   'number': 50397,
#   'title': 'STYLE pre-commit check to ensure that test functions name starts with test',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-22T16:42:04Z',
#   'updated_at': '2022-12-22T17:10:17Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50397',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50397',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50397.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50397.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #50379 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50397/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50397/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50396',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50396/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50396/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50396/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50396',
#   'id': 1508154861,
#   'node_id': 'PR_kwDOAA0YD85GDmxd',
#   'number': 50396,
#   'title': 'BUG/COMPAT: fix assert_* functions for nested arrays with latest numpy',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 76865106,
#     'node_id': 'MDU6TGFiZWw3Njg2NTEwNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Compat',
#     'name': 'Compat',
#     'color': '0052cc',
#     'default': False,
#     'description': 'pandas objects compatability with Numpy or Python functions'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/100',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/100',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/100/labels',
#    'id': 8654991,
#    'node_id': 'MI_kwDOAA0YD84AhBCP',
#    'number': 100,
#    'title': '1.5.3',
#    'description': 'on-merge: backport to 1.5.x',
#    'creator': {'login': 'datapythonista',
#     'id': 10058240,
#     'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/datapythonista',
#     'html_url': 'https://github.com/datapythonista',
#     'followers_url': 'https://api.github.com/users/datapythonista/followers',
#     'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#     'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#     'repos_url': 'https://api.github.com/users/datapythonista/repos',
#     'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 15,
#    'closed_issues': 49,
#    'state': 'open',
#    'created_at': '2022-11-15T04:46:08Z',
#    'updated_at': '2022-12-22T16:19:57Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-12-22T16:17:39Z',
#   'updated_at': '2022-12-22T17:12:24Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50396',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50396',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50396.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50396.patch',
#    'merged_at': None},
#   'body': "This adds tests for `assert_almost_equal` (used by `assert_series_equal` et al in case of object dtype arrays) that all pass on pandas main with released numpy (except for two cases with dict of array), and fixes the implementation of `array_equivalent` (used by `assert_almost_equal`) to return False instead of raising an error if numpy cannot compare the arrays (numpy 1.25.dev starts to raise for this instead of returning False).\r\n\r\nI also added a bunch of equivalent tests for `array_equivalent` itself, but those don't all pass (and added xfails). Trying to fix those as well might need more extensive changes, and I would prefer to do that separate from this PR (to keep this one possible to backport).\r\n\r\nSee https://github.com/pandas-dev/pandas/issues/50360#issuecomment-1362678681 for an illustration of the behaviour that changed in numpy 1.25.dev that causes this.\r\n\r\n- [x] closes https://github.com/pandas-dev/pandas/issues/50360\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50396/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50396/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50395',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50395/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50395/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50395/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50395',
#   'id': 1508119987,
#   'node_id': 'I_kwDOAA0YD85Z5BWz',
#   'number': 50395,
#   'title': 'ENH: Adding support for calamine as Excel reader engine',
#   'user': {'login': 'abielr',
#    'id': 168236,
#    'node_id': 'MDQ6VXNlcjE2ODIzNg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/168236?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/abielr',
#    'html_url': 'https://github.com/abielr',
#    'followers_url': 'https://api.github.com/users/abielr/followers',
#    'following_url': 'https://api.github.com/users/abielr/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/abielr/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/abielr/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/abielr/subscriptions',
#    'organizations_url': 'https://api.github.com/users/abielr/orgs',
#    'repos_url': 'https://api.github.com/users/abielr/repos',
#    'events_url': 'https://api.github.com/users/abielr/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/abielr/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 49254273,
#     'node_id': 'MDU6TGFiZWw0OTI1NDI3Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Excel',
#     'name': 'IO Excel',
#     'color': 'bfe5bf',
#     'default': False,
#     'description': 'read_excel, to_excel'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-12-22T15:51:43Z',
#   'updated_at': '2022-12-22T16:37:47Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Feature Type\n\n- [X] Adding new functionality to pandas\n\n- [ ] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nReading Excel files in Pandas is considerably slower than in some alternative data frame tools, for example the `readxl` package in R can read Excel files much faster. The Rust `calamine` library can read Excel files much faster than other engines supported by Pandas, and there is an existing Python binding to it, [python-calamine](https://github.com/dimastbk/python-calamine). I would like to request that Pandas add official support for `calamine`, so that users can read an Excel file like:\r\n\r\n`pd.read_excel("test.xlsx", engine="calamine")`\n\n### Feature Description\n\nThe `python-calamine` package already implements code that enables the calamine engine in Pandas, see the examples using `pandas_monkeypatch()` at the bottom of their Github README. The code to enable this is [here](https://github.com/dimastbk/python-calamine/blob/master/python/python_calamine/pandas.py)\r\n\r\nAlthough `python-calamine` already implements the necessary features to use the library with Pandas, I am unclear on how similar the behavior is between `calamine` and other engines that Pandas supports like `openpyxl`. I am hoping that by bringing `calamine` in as an officially supported engine that Pandas unit tests will confirm consistent behavior across `calamine` and other engines. \n\n### Alternative Solutions\n\nNone\n\n### Additional Context\n\n_No response_',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50395/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50395/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50394',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50394/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50394/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50394/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50394',
#   'id': 1508061837,
#   'node_id': 'PR_kwDOAA0YD85GDSIx',
#   'number': 50394,
#   'title': 'CLN remove unused functions',
#   'user': {'login': 'ShashwatAgrawal20',
#    'id': 72117025,
#    'node_id': 'MDQ6VXNlcjcyMTE3MDI1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72117025?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ShashwatAgrawal20',
#    'html_url': 'https://github.com/ShashwatAgrawal20',
#    'followers_url': 'https://api.github.com/users/ShashwatAgrawal20/followers',
#    'following_url': 'https://api.github.com/users/ShashwatAgrawal20/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ShashwatAgrawal20/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ShashwatAgrawal20/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ShashwatAgrawal20/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ShashwatAgrawal20/orgs',
#    'repos_url': 'https://api.github.com/users/ShashwatAgrawal20/repos',
#    'events_url': 'https://api.github.com/users/ShashwatAgrawal20/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ShashwatAgrawal20/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-22T15:14:29Z',
#   'updated_at': '2022-12-22T17:24:55Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50394',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50394',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50394.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50394.patch',
#    'merged_at': None},
#   'body': 'closes #50393\r\n\r\nCLN remove _assert_not_frame_equal_both?',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50394/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50394/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50393',
#   'id': 1507803479,
#   'node_id': 'I_kwDOAA0YD85Z30FX',
#   'number': 50393,
#   'title': 'CLN remove _assert_not_frame_equal_both?',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None},
#    {'id': 717120670,
#     'node_id': 'MDU6TGFiZWw3MTcxMjA2NzA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/good%20first%20issue',
#     'name': 'good first issue',
#     'color': '0e8a16',
#     'default': True,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'ShashwatAgrawal20',
#    'id': 72117025,
#    'node_id': 'MDQ6VXNlcjcyMTE3MDI1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72117025?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ShashwatAgrawal20',
#    'html_url': 'https://github.com/ShashwatAgrawal20',
#    'followers_url': 'https://api.github.com/users/ShashwatAgrawal20/followers',
#    'following_url': 'https://api.github.com/users/ShashwatAgrawal20/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ShashwatAgrawal20/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ShashwatAgrawal20/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ShashwatAgrawal20/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ShashwatAgrawal20/orgs',
#    'repos_url': 'https://api.github.com/users/ShashwatAgrawal20/repos',
#    'events_url': 'https://api.github.com/users/ShashwatAgrawal20/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ShashwatAgrawal20/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'ShashwatAgrawal20',
#     'id': 72117025,
#     'node_id': 'MDQ6VXNlcjcyMTE3MDI1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/72117025?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ShashwatAgrawal20',
#     'html_url': 'https://github.com/ShashwatAgrawal20',
#     'followers_url': 'https://api.github.com/users/ShashwatAgrawal20/followers',
#     'following_url': 'https://api.github.com/users/ShashwatAgrawal20/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/ShashwatAgrawal20/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/ShashwatAgrawal20/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/ShashwatAgrawal20/subscriptions',
#     'organizations_url': 'https://api.github.com/users/ShashwatAgrawal20/orgs',
#     'repos_url': 'https://api.github.com/users/ShashwatAgrawal20/repos',
#     'events_url': 'https://api.github.com/users/ShashwatAgrawal20/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/ShashwatAgrawal20/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 5,
#   'created_at': '2022-12-22T12:37:10Z',
#   'updated_at': '2022-12-22T16:58:10Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "Doesn't look like this is used anywhere\r\n\r\nhttps://github.com/pandas-dev/pandas/blob/07b363ea8eee184df30b54bfae9acd04511e1cda/pandas/tests/util/test_assert_frame_equal.py#L55-L71",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50393/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50392',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50392/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50392/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50392/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50392',
#   'id': 1507777076,
#   'node_id': 'I_kwDOAA0YD85Z3to0',
#   'number': 50392,
#   'title': 'CI unpin numpy',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-22T12:19:26Z',
#   'updated_at': '2022-12-22T12:19:26Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "numpy 1.24.0 can't be used with numba. once https://github.com/numba/numba/pull/8620 is merged, and this is fixed in numba, we can unpin numpy in CI",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50392/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50392/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50390',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50390/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50390/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50390/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50390',
#   'id': 1507564558,
#   'node_id': 'I_kwDOAA0YD85Z25wO',
#   'number': 50390,
#   'title': 'ENH: Rolling with window=offset and step=offset',
#   'user': {'login': 'harrylojames',
#    'id': 51630653,
#    'node_id': 'MDQ6VXNlcjUxNjMwNjUz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51630653?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/harrylojames',
#    'html_url': 'https://github.com/harrylojames',
#    'followers_url': 'https://api.github.com/users/harrylojames/followers',
#    'following_url': 'https://api.github.com/users/harrylojames/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/harrylojames/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/harrylojames/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/harrylojames/subscriptions',
#    'organizations_url': 'https://api.github.com/users/harrylojames/orgs',
#    'repos_url': 'https://api.github.com/users/harrylojames/repos',
#    'events_url': 'https://api.github.com/users/harrylojames/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/harrylojames/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-22T09:50:05Z',
#   'updated_at': '2022-12-22T09:50:05Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Feature Type\n\n- [X] Adding new functionality to pandas\n\n- [ ] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nWould be really great to be able to write df.rolling(window="7d", step="1d)\r\n\r\nCurrently this returns NotImplementedError: step is not supported with frequency windows\n\n### Feature Description\n\n.\n\n### Alternative Solutions\n\n.\n\n### Additional Context\n\n_No response_',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50390/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50390/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50389',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50389/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50389/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50389/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50389',
#   'id': 1507101341,
#   'node_id': 'PR_kwDOAA0YD85F__X_',
#   'number': 50389,
#   'title': 'ENH: Add cumsum to ArrowExtensionArray',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-22T00:58:00Z',
#   'updated_at': '2022-12-22T08:58:30Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50389',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50389',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50389.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50389.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nDon't think a whatsnew is needed since `EA._accumulate` was added in 2.0\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50389/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50389/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50388',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50388/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50388/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50388/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50388',
#   'id': 1507017355,
#   'node_id': 'PR_kwDOAA0YD85F_tAP',
#   'number': 50388,
#   'title': 'WEB: Add backoff + retry for Github API calls',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'},
#    {'id': 1508144531,
#     'node_id': 'MDU6TGFiZWwxNTA4MTQ0NTMx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Web',
#     'name': 'Web',
#     'color': '23ef97',
#     'default': False,
#     'description': 'pandas website'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-12-21T23:02:48Z',
#   'updated_at': '2022-12-22T17:22:00Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50388',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50388',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50388.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50388.patch',
#    'merged_at': None},
#   'body': 'Hopefully to help the doc and web build sometimes failing because of hitting the rate limit of the GIthub API\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "web/pandas_web.py", line 403, in <module>\r\n    main(args.source_path, args.target_path, args.base_url, args.ignore_io_errors)\r\n  File "web/pandas_web.py", line 349, in main\r\n    context = get_context(config_fname, ignore_io_errors, base_url=base_url)\r\n  File "web/pandas_web.py", line 305, in get_context\r\n    context = preprocessor(context)\r\n  File "/home/runner/work/pandas/pandas/web/pandas_web.py", line 172, in maintainers_add_info\r\n    resp.raise_for_status()\r\n  File "/home/runner/micromamba/envs/test/lib/python3.8/site-packages/requests/models.py", line 1021, in raise_for_status\r\n    raise HTTPError(http_error_msg, response=self)\r\nrequests.exceptions.HTTPError: 403 Client Error: rate limit exceeded for url: https://api.github.com/users/shoyer\r\n\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50388/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50370/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50370/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50369',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50369/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50369/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50369/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50369',
#   'id': 1505615001,
#   'node_id': 'PR_kwDOAA0YD85F6-ky',
#   'number': 50369,
#   'title': 'ENH/API: preserve non-nano in to_datetime',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-12-21T02:35:02Z',
#   'updated_at': '2022-12-21T23:46:40Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50369',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50369',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50369.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50369.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50369/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50369/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50367',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50367/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50367/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50367/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/50367',
#   'id': 1505392495,
#   'node_id': 'I_kwDOAA0YD85Zundv',
#   'number': 50367,
#   'title': 'BUG: Groupby mean differs depending on where `np.inf` value was introduced',
#   'user': {'login': 'ncclementi',
#    'id': 7526622,
#    'node_id': 'MDQ6VXNlcjc1MjY2MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7526622?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ncclementi',
#    'html_url': 'https://github.com/ncclementi',
#    'followers_url': 'https://api.github.com/users/ncclementi/followers',
#    'following_url': 'https://api.github.com/users/ncclementi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ncclementi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ncclementi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ncclementi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ncclementi/orgs',
#    'repos_url': 'https://api.github.com/users/ncclementi/repos',
#    'events_url': 'https://api.github.com/users/ncclementi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ncclementi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 2822342,
#     'node_id': 'MDU6TGFiZWwyODIyMzQy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Missing-data',
#     'name': 'Missing-data',
#     'color': 'd7e102',
#     'default': False,
#     'description': 'np.nan, pd.NaT, pd.NA, dropna, isnull, interpolate'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 7,
#   'created_at': '2022-12-20T22:27:56Z',
#   'updated_at': '2022-12-21T15:42:10Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the main branch of pandas.\r\n\r\nEDIT: editing RE as initial one had some issues, the posts that say they couldn\'t reproduce is based on the initial post with some errors. \r\n\r\n\r\n\r\n### Reproducible Example (latest)\r\n\r\n```python\r\n#When `inf` is in at the end of the columns\r\n\r\nd ={"x": [1, 2, 3, 4, 5, np.inf], #notice inf at the end\r\n    "y": [1, 1 ,1, 1, 1, 1],\r\n    "z": ["alice", "bob", "alice", "bob", \r\n          "alice", "bob",]}\r\n          \r\npdf = pd.DataFrame(d).astype({"x": "float32", "y": "float32","z": "string"})\r\n\r\npdf.groupby("z").x.mean()\r\n"""returns\r\nz\r\nalice    3.0\r\nbob      inf\r\nName: x, dtype: float32\r\n""" \r\n#When `inf` is in at the beginning of the columns\r\n\r\nd2 ={"x": [ np.inf, 1, 2, 3, 4, 5], #inf at the beginning\r\n    "y": [1, 1 ,1, 1, 1, 1],\r\n    "z": ["alice", "bob", "alice", "bob", \r\n          "alice", "bob",]}\r\n          \r\npdf2 = pd.DataFrame(d).astype({"x": "float32", "y": "float32","z": "string"})\r\n\r\npdf2.groupby("z").x.mean()\r\n"""returns\r\nz\r\nalice    NaN\r\nbob      3.0\r\nName: x, dtype: float32\r\n"""   \r\n```\r\n\r\n### Issue Description\r\n\r\nRegardless of how `inf` values are inserted in the dataframe the groupby aggregation should be consistent. \r\n\r\n### Expected Behavior\r\n\r\nIt is not clear  to me whether it should return `NaN` or `Inf` but it should be consistent\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\npandas=1.5.2\r\nnumpy=1.23.5 / tried 1.24.0 too\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50367/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50367/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50366',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50366/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50366/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50366/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50366',
#   'id': 1505293806,
#   'node_id': 'PR_kwDOAA0YD85F57R8',
#   'number': 50366,
#   'title': "ERR non-ISO formats don't show position of error ",
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None},
#    {'id': 42670965,
#     'node_id': 'MDU6TGFiZWw0MjY3MDk2NQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Error%20Reporting',
#     'name': 'Error Reporting',
#     'color': 'ffa0ff',
#     'default': False,
#     'description': 'Incorrect or improved errors from pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-12-20T21:17:43Z',
#   'updated_at': '2022-12-22T09:28:06Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50366',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50366',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50366.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50366.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #50361 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\n---\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50366/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50366/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50364',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50364/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50364/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50364/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50364',
#   'id': 1504959845,
#   'node_id': 'PR_kwDOAA0YD85F40Or',
#   'number': 50364,
#   'title': 'BUG: str dtype ignored for column with dot',
#   'user': {'login': 'natmokval',
#    'id': 91160475,
#    'node_id': 'MDQ6VXNlcjkxMTYwNDc1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91160475?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/natmokval',
#    'html_url': 'https://github.com/natmokval',
#    'followers_url': 'https://api.github.com/users/natmokval/followers',
#    'following_url': 'https://api.github.com/users/natmokval/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/natmokval/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/natmokval/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/natmokval/subscriptions',
#    'organizations_url': 'https://api.github.com/users/natmokval/orgs',
#    'repos_url': 'https://api.github.com/users/natmokval/repos',
#    'events_url': 'https://api.github.com/users/natmokval/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/natmokval/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2022-12-20T17:18:00Z',
#   'updated_at': '2022-12-22T11:06:25Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/50364',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/50364',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/50364.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/50364.patch',
#    'merged_at': None},
#   'body': "- [x] closes #50270\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\nThis is a direct attempt to fix the problem with 'dot' in strings. Maybe it would be better to use for this purpose attribute `_no_thousands_columns`.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50364/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50364/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
len(data)
# Out:
# 30

# %%
data[0]['user']
# Out:
# {'login': 'lithomas1',
#  'id': 47963215,
#  'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/lithomas1',
#  'html_url': 'https://github.com/lithomas1',
#  'followers_url': 'https://api.github.com/users/lithomas1/followers',
#  'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#  'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#  'repos_url': 'https://api.github.com/users/lithomas1/repos',
#  'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
data[0]['user']['id']
# Out:
# 47963215

# %%
max_iter = 10
for i in range(len(data)):
    print(data[i]['user']['id'])
    max_iter -= 1
    if max_iter == 0:
        break
# Out:
# 47963215
# 358225
# 91160475
# 33491632
# 1020496
# 168236
# 72117025
# 33491632
# 33491632
# 51630653

# %%
pd.DataFrame(data).head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                             html_url          id  \
# 0    https://github.com/pandas-dev/pandas/pull/50400  1508254094
# 1  https://github.com/pandas-dev/pandas/issues/50399  1508214211
# 2    https://github.com/pandas-dev/pandas/pull/50398  1508195560
# 3    https://github.com/pandas-dev/pandas/pull/50397  1508193487
# 4    https://github.com/pandas-dev/pandas/pull/50396  1508154861
#
#                node_id  number  \
# 0  PR_kwDOAA0YD85GD9HI   50400
# 1   I_kwDOAA0YD85Z5YXD   50399
# 2  PR_kwDOAA0YD85GDvwX   50398
# 3  PR_kwDOAA0YD85GDvSA   50397
# 4  PR_kwDOAA0YD85GDmxd   50396
#
#                                                title  ... closed_at  \
# 0  BUG: Index with null value not serialized corr...  ...      None
# 1       BUG: Rolling.mean downcasts extension dtypes  ...      None
# 2  ENH: add math mode to formatter escape="latex-...  ...      None
# 3  STYLE pre-commit check to ensure that test fun...  ...      None
# 4  BUG/COMPAT: fix assert_* functions for nested ...  ...      None
#
#   author_association active_lock_reason  draft  \
# 0             MEMBER               None   True
# 1               NONE               None    NaN
# 2        CONTRIBUTOR               None  False
# 3             MEMBER               None  False
# 4             MEMBER               None  False
#
#                                         pull_request  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1                                                NaN
# 2  {'url': 'https://api.github.com/repos/pandas-d...
# 3  {'url': 'https://api.github.com/repos/pandas-d...
# 4  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                                 body  \
# 0  - [ ] closes #31801 (Replace xxxx with the Git...
# 1  ### Pandas version checks\n\n- [X] I have chec...
# 2  - [x] closes #50040\r\n- [x] All [code checks ...
# 3  - [ ] closes #50379 (Replace xxxx with the Git...
# 4  This adds tests for `assert_almost_equal` (use...
#
#                                            reactions  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1  {'url': 'https://api.github.com/repos/pandas-d...
# 2  {'url': 'https://api.github.com/repos/pandas-d...
# 3  {'url': 'https://api.github.com/repos/pandas-d...
# 4  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                         timeline_url performed_via_github_app  \
# 0  https://api.github.com/repos/pandas-dev/pandas...                     None
# 1  https://api.github.com/repos/pandas-dev/pandas...                     None
# 2  https://api.github.com/repos/pandas-dev/pandas...                     None
# 3  https://api.github.com/repos/pandas-dev/pandas...                     None
# 4  https://api.github.com/repos/pandas-dev/pandas...                     None
#
#   state_reason
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#
# [5 rows x 30 columns]

# %%
pd.DataFrame(data, columns = ['url', 'repository_url', 'labels_url'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...

# %%
pd.DataFrame(data, columns = ['url', 'repository_url', 'labels_url', 'user'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                  user
# 0   {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 1   {'login': 'bollard', 'id': 358225, 'node_id': ...
# 2   {'login': 'natmokval', 'id': 91160475, 'node_i...
# 3   {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 4   {'login': 'jorisvandenbossche', 'id': 1020496,...
# 5   {'login': 'abielr', 'id': 168236, 'node_id': '...
# 6   {'login': 'ShashwatAgrawal20', 'id': 72117025,...
# 7   {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 8   {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 9   {'login': 'harrylojames', 'id': 51630653, 'nod...
# 10  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 11  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 12  {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 13  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 14  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 15  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 16  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 17  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 18  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 19  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 20  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 21  {'login': 'robsdedude', 'id': 4061254, 'node_i...
# 22  {'login': 'jesrael', 'id': 10682573, 'node_id'...
# 23  {'login': 'adrien-berchet', 'id': 11536226, 'n...
# 24  {'login': 'datapythonista', 'id': 10058240, 'n...
# 25  {'login': 'datapythonista', 'id': 10058240, 'n...
# 26  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 27  {'login': 'ncclementi', 'id': 7526622, 'node_i...
# 28  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 29  {'login': 'natmokval', 'id': 91160475, 'node_i...

# %%
temp_file = pd.DataFrame(data, columns = ['url', 'repository_url', 'labels_url', 'user'])
temp_file.to_csv('data/sample-csv/0227_json_ex.csv')
